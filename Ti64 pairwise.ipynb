# %%
import pandas as pd

# %%
X=pd.read_csv('/Users/owner/Downloads/Ti64 data.csv')

# %%
import seaborn as sns

# %%
palette = {"a":(1,0,0,0.8),"e":(0.75,0.75,0.75,0.4), "b":(0,0,1,0.8)}

# %%
sns.pairplot(X,hue="rank", palette=palette, plot_kws={'edgecolor':'none'}, diag_kws={'edgecolor':'gray', 'linewidth':1})

# %%
X1=pd.read_csv('/Users/owner/Downloads/Ti64 data(no ved more than 600).csv')
sns.pairplot(X1,hue="rank", palette=palette, plot_kws={'edgecolor':'none'}, diag_kws={'edgecolor':'gray', 'linewidth':1})
